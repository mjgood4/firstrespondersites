# %%
#packages
import pandas as pd
import numpy as np
import matplotlib as plt
import scipy

import warnings
import sqlite3

from numpy import asarray
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn import metrics
from xgboost import XGBRFRegressor

# %%
def create_connection(path):
    connection = None 
    connection = sqlite3.connect(path)
    connection.text_factory = str

    return connection

# %%
##Update this, its probably not where your DB is
con = create_connection('C:\\Data\\fire_data_v4.db\\fire_data_v4.db')

# %%
    cur = con.cursor()

    df = pd.read_sql("select calls_for_service.analysis_neighborhoods as neighborhood " \
        ", calls_for_service.call_number " \
        ", calls_for_service.incident_number " \
        ", floating_catchment_output.[index] " \
        ", floating_catchment_output.zone_idx " \
        ", floating_catchment_output.accessibility_score " \
        ", floating_catchment_output.scenario_name " \
        ", calls_for_service.on_scene_dttm " \
        ", calls_for_service.response_dttm   " \
        "from floating_catchment_output " \
        "inner join zone_idx_to_incident on  " \
        "zone_idx_to_incident.zone_idx = floating_catchment_output.zone_idx " \
        "inner join calls_for_service on calls_for_service.incident_number = zone_idx_to_incident.incident_number " \
        "where calls_for_service.unit_type in ('TRUCK', 'ENGINE') " \
        "and scenario_name = 'baseline'",con = con)

# %%
#do some date math
df['on_scene_dttm'] = pd.to_datetime(df['on_scene_dttm'])
df['response_dttm'] = pd.to_datetime(df['response_dttm'])
df['arrival_time'] = (df['on_scene_dttm'] - df['response_dttm'])
df['minutes'] = (df.arrival_time.dt.seconds) / 60
df['seconds'] = (df.arrival_time.dt.seconds) 
df['hour_of_day'] = df['on_scene_dttm'].dt.hour
df['dayflag'] = (df.response_dttm.dt.hour > 5) & (df.response_dttm.dt.hour < 18)

df = df[df['dayflag'].notna()]
df = df[df['hour_of_day'].notna()]

# %%
#rool up accessibility and minutes to zone
df_ag = df.groupby(["zone_idx","hour_of_day", "dayflag"], as_index=False).agg({"accessibility_score":"mean", "minutes":"mean"})
print(len(df_ag))
df_ag.head()
# Out:
# 6028
#    zone_idx  hour_of_day  dayflag  accessibility_score   minutes
# 0         8          0.0    False             0.000803  2.800000
# 1         8          2.0    False             0.000803  3.394444
# 2         8          3.0    False             0.000803  2.761111
# 3         8          4.0    False             0.000803  1.816667
# 4         8          5.0    False             0.000803  2.775000

# %%
# hide the warings.
# I mean if it was really important it would just be an error, so blissfully ignore
warnings.filterwarnings('ignore')

# set the training variables
df_ag.target_to_predict = 'minutes'
df_ag.predictors = ['zone_idx', 'hour_of_day', 'dayflag', 'accessibility_score']

df_ag.x = df_ag[df_ag.predictors].values
df_ag.y = df_ag[df_ag.target_to_predict].values

df_ag.x_train, df_ag.x_test, df_ag.y_train, df_ag.y_test = train_test_split(df_ag.x, df_ag.y, test_size=0.8, random_state=42)

# %%
#copy/paste code:

def create_model(md):
    #RegModel = XGBRegressor(max_depth=3, learning_rate=0.1, n_estimators=500, objective='reg:linear', booster='gbtree')
    md.model = XGBRFRegressor(n_estimators=300, subsample=0.5, colsample_bynode=0.8, min_child_weight=3)

    #Printing all the parameters of XGBoost
    print(md.model)
    
    #Creating the model on Training Data
    md.XGB = md.model.fit(md.x_train, md.y_train)
    
    prediction = md.XGB.predict(md.x_test)

    #Measuring Goodness of fit in Training data
    print('R2 Value:', metrics.r2_score(md.y_train, md.XGB.predict(md.x_train)))

    #Measuring accuracy on Testing Data
    print('md.ytest', md.y_test)
    print('Accuracy', 100 - (np.mean(np.abs((md.y_test - prediction)) / np.mean(md.y_test)) * 100))
    print('Accuracy', 100 - (np.mean(np.abs((md.y_test - prediction) / md.y_test)) * 100))

    #Plotting the feature importance for Top 10 most important columns 
    # %matplotlib inline
    feature_importances = pd.Series(md.XGB.feature_importances_, index = md.predictors)
    feature_importances.nlargest(10).plot(kind = 'barh')

# %%
create_model(df_ag)
# Out:
# XGBRFRegressor(base_score=None, booster=None, colsample_bylevel=None,
#                colsample_bytree=None, enable_categorical=False, gamma=None,
#                gpu_id=None, importance_type=None, interaction_constraints=None,
#                max_delta_step=None, max_depth=None, min_child_weight=3,
#                missing=nan, monotone_constraints=None, n_estimators=300,
#                n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', predictor=None, random_state=None,
#                reg_alpha=None, scale_pos_weight=None, subsample=0.5,
#                tree_method=None, validate_parameters=None, verbosity=None)
# R2 Value: 0.2294815540311662
# md.ytest [3.47333333 2.23333333 6.58809524 ... 2.95961538 2.99313725 2.60448718]
# Accuracy 68.20783173886971
# Accuracy -inf

# %%
cur = con.cursor()
df_scenarios = pd.read_sql(('select distinct scenario_name from simulation_floating_catchment_output'), con=con)

# %%
prediction_stats = []
predictions = []
compare_errors = []

for i in range(len(df_scenarios)):
    #Get data to predict
    cur = con.cursor()
    scenario_name = df_scenarios["scenario_name"][i]
    hour_of_day = 17
    dayFlag = True
    df_to_predict = pd.read_sql(('select zone_idx, accessibility_score, ? as hour_of_day, ? as dayflag from simulation_floating_catchment_output where scenario_name = ?'), con=con,params=[hour_of_day, dayFlag, scenario_name])
    #assumptions
    df_to_predict["dayflag"] = dayFlag
    df_to_predict["hour_of_day"] = hour_of_day
    print("Predicting: " + scenario_name + ", records:" + str(df_to_predict.count()))
    
    prediction = df_ag.XGB.predict(df_to_predict[["zone_idx", "accessibility_score", "hour_of_day", "dayflag"]])
    print(len(prediction))
    df_to_predict['predicted_minutes'] = prediction.copy()

    compare_error = df_ag.merge(df_to_predict, how="inner", on=["zone_idx", "hour_of_day","dayflag"])

    compare_error["minutes_delta"] = compare_error["minutes"] - compare_error["predicted_minutes"]
    compare_error["accessibility_delta"] = (compare_error["accessibility_score_x"] - compare_error["accessibility_score_y"])
    compare_error['scenario_name'] = scenario_name
    
    compare_errors.append(compare_error.copy())
    sq_error_sum = np.sum(np.square(np.array(compare_error["minutes"]) - np.array(compare_error["predicted_minutes"])))
    sq_error_mean = np.sum(np.square(np.average(compare_error["minutes"]) - np.array(compare_error["minutes"])))

    (r, p) = scipy.stats.pearsonr(compare_error["minutes_delta"], compare_error["accessibility_delta"])

    prediction_stats.append((scenario_name, sq_error_sum.copy(), sq_error_mean.copy(), r,p))
    df_to_predict["scenario_name"] = scenario_name
    predictions.append(df_to_predict.copy())
# Out:
# Predicting: new_station_235, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_177, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_176, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_319, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_274, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_271, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_292, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_236, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_273, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_277, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_296, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_293, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_139, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_216, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_288, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_272, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_294, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_258, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_269, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_318, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_255, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_256, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_259, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_276, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_297, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_278, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_315, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_196, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_299, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_290, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_253, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_295, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_298, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_197, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_313, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_291, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_132, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_117, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_112, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_94, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_93, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_153, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_113, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_115, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_154, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_74, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_134, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_135, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_133, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_131, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_214, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_213, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_173, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_252, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_232, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_193, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_212, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_234, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_231, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_341, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_362, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_363, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_360, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_381, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_340, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_361, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_382, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_311, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_251, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_310, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_250, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_249, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_289, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_246, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_286, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_265, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_275, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_217, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_215, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_233, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_195, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_199, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_179, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_198, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_158, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_157, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_159, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_178, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_266, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_306, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_287, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_285, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_307, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_92, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_71, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_110, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_91, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_130, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_90, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_51, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_70, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_68, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_149, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_108, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_129, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_111, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_107, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_50, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_88, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_10, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_58, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_39, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_56, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_79, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_12, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_34, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_59, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_38, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_11, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_36, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_76, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_13, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_37, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_78, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_77, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_54, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_57, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_14, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_55, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_187, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_189, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_207, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_229, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_248, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_227, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_228, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_188, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_169, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_209, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_168, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_376, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_337, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_338, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_335, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_356, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_316, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_317, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_375, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_355, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_334, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_48, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_49, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_30, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_29, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_28, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_9, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_305, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_175, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_156, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_136, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_174, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_342, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_211, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_191, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_190, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_230, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_83, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_145, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_104, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_167, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_184, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_146, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_144, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_166, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_85, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_205, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_185, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_164, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_124, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_126, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_186, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_98, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_119, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_138, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_137, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_238, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_257, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_32, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_72, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_52, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_31, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_53, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_148, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_147, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_208, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_109, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_128, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_67, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_69, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_116, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_155, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_73, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_114, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_95, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_75, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_210, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_264, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_243, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_223, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_263, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_245, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_204, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_237, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_171, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_172, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_194, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_192, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_312, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_330, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_332, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_206, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_226, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_47, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_327, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_364, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_35, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_96, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_97, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_118, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_99, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_151, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_150, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_152, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_378, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_377, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_397, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_398, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_105, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_86, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_106, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_103, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_165, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_66, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_84, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_127, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_89, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_87, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_309, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_331, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_270, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_8, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_254, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_308, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_339, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_336, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_239, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_170, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_247, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_125, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_218, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_329, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_244, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_357, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_268, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_333, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_396, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_27, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_219, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_183, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_33, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_225, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_203, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_224, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_353, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_354, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_314, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_328, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_383, records:zone_idx               266
# accessibility_score    266
# hour_of_day            266
# dayflag                266
# dtype: int64
# 266
# Predicting: new_station_326, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_267, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265
# Predicting: new_station_352, records:zone_idx               265
# accessibility_score    265
# hour_of_day            265
# dayflag                265
# dtype: int64
# 265

# %%
print(pd.concat(compare_errors)[['minutes_delta', 'accessibility_delta', 'scenario_name', 'zone_idx']].to_csv('delta_analysis_hour_of_day.csv'))
# Out:
# None

# %%
sts = pd.DataFrame(prediction_stats)
sts = sts.rename(columns={0: "scenario_name", 1: "sq_avg_error", 2:"sq_sum_error", 3:"r_value",4:"p_value"}, errors="raise")

sts.to_csv('prediction_stats_hour_of_day.csv')

# %%
pd.concat(predictions).to_csv('predictions_hour_of_day.csv')

# %%
df_ag.to_csv('aggregated.csv')
